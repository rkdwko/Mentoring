# %%
import pandas as pd

# %%
df1 = pd.read_csv("C:/Users/709-000/Desktop/새 폴더/연도별 추출/유동인구2018test.csv")
df1
# Out:
#       Unnamed: 0  stdr_yy_cd  stdr_qu_cd trdar_se_cd trdar_se_cd_nm  trdar_cd  \
# 0          23838        2018           1           A           골목상권   1000001
# 1          23839        2018           1           A           골목상권   1000002
# 2          23840        2018           1           A           골목상권   1000003
# 3          23841        2018           1           A           골목상권   1000004
# 4          23842        2018           1           A           골목상권   1000005
# 5          23843        2018           1           A           골목상권   1000006
# 6          23844        2018           1           A           골목상권   1000007
# 7          23845        2018           1           A           골목상권   1000008
# 8          23846        2018           1           A           골목상권   1000009
# 9          23847        2018           1           A           골목상권   1000010
# 10         23848        2018           1           A           골목상권   1000011
# ...

# %%
df1['code'] = df1['trdar_cd']

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'stdr_yy_cd', 'stdr_qu_cd', 'trdar_se_cd',
#        'trdar_se_cd_nm', 'trdar_cd', 'trdar_cd_nm', 'tot_flpop_co', 'code'],
#       dtype='object')

# %%
df1.groupby('trdar_cd').mean()
# Out:
#           Unnamed: 0  stdr_yy_cd  stdr_qu_cd  tot_flpop_co       code
# trdar_cd
# 1000001      26080.5      2018.0         2.5     181174.00  1000001.0
# 1000002      26081.5      2018.0         2.5     261543.75  1000002.0
# 1000003      26082.5      2018.0         2.5     134808.75  1000003.0
# 1000004      26083.5      2018.0         2.5     349808.75  1000004.0
# 1000005      26084.5      2018.0         2.5      32022.00  1000005.0
# 1000006      26085.5      2018.0         2.5      67089.00  1000006.0
# 1000007      26086.5      2018.0         2.5      58997.50  1000007.0
# 1000008      26087.5      2018.0         2.5      32681.25  1000008.0
# 1000009      26088.5      2018.0         2.5      32266.75  1000009.0
# 1000010      26089.5      2018.0         2.5     254794.25  1000010.0
# 1000011      26090.5      2018.0         2.5      97681.00  1000011.0
# 1000012      26091.5      2018.0         2.5     151272.00  1000012.0
# ...

# %%
df1.unstack
# Out:
# <bound method DataFrame.unstack of       Unnamed: 0  stdr_yy_cd  stdr_qu_cd trdar_se_cd trdar_se_cd_nm  trdar_cd  \
# 0          23838        2018           1           A           골목상권   1000001
# 1          23839        2018           1           A           골목상권   1000002
# 2          23840        2018           1           A           골목상권   1000003
# 3          23841        2018           1           A           골목상권   1000004
# 4          23842        2018           1           A           골목상권   1000005
# 5          23843        2018           1           A           골목상권   1000006
# 6          23844        2018           1           A           골목상권   1000007
# 7          23845        2018           1           A           골목상권   1000008
# 8          23846        2018           1           A           골목상권   1000009
# 9          23847        2018           1           A           골목상권   1000010
# 10         23848        2018           1           A           골목상권   1000011
# ...

# %%
df1['trdar_cd'] = df..map(df.A)
