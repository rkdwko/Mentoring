# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/709-000/Desktop/새 폴더/서울시 상권분석 데이터/서울시 우리마을가게 상권분석서비스(상권-추정매출).csv")

# %%
df
# Out:
#         기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드    상권_코드_명 서비스_업종_코드  \
# 0          2014         1        D       발달상권  1001119     영등포역_2  CS200003
# 1          2014         1        D       발달상권  1001050      교대역_1  CS200007
# 2          2014         1        A       골목상권  1000240     망우로73길  CS200007
# 3          2014         1        A       골목상권  1000472    마포대로20길  CS200008
# 4          2018         1        A       골목상권  1000275     보문로26길  CS100001
# 5          2018         1        A       골목상권  1000116    왕십리로14길  CS100001
# 6          2018         1        A       골목상권  1000685     경인로80길  CS100001
# 7          2018         1        A       골목상권  1000797  남부순환로161길  CS100001
# 8          2018         1        A       골목상권  1000181     망우로21길  CS100001
# 9          2018         1        R       전통시장  1001409   화곡중앙골목시장  CS100001
# ...         ...       ...      ...        ...      ...        ...       ...
# ...

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(df.loc[:138722])
# Out:
#         기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드         상권_코드_명  \
# 0          2014         1        D       발달상권  1001119          영등포역_2
# 1          2014         1        D       발달상권  1001050           교대역_1
# 2          2014         1        A       골목상권  1000240          망우로73길
# 3          2014         1        A       골목상권  1000472         마포대로20길
# 4          2018         1        A       골목상권  1000275          보문로26길
# 5          2018         1        A       골목상권  1000116         왕십리로14길
# 6          2018         1        A       골목상권  1000685          경인로80길
# 7          2018         1        A       골목상권  1000797       남부순환로161길
# 8          2018         1        A       골목상권  1000181          망우로21길
# 9          2018         1        R       전통시장  1001409        화곡중앙골목시장
# ...         ...       ...      ...        ...      ...             ...
# 138713     2018         4        D       발달상권  1001208  서울 중구 을지로3가역_2
# ...

# %%
sales2013 = df[df['기준_년_코드'] == 2013]

# %%
sales2013
# Out:
#         기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드    상권_코드_명 서비스_업종_코드  \
# 440655     2013         1        A       골목상권  1000079    한강대로43길  CS100003
# 522971     2013         3        A       골목상권  1000200     장한로27길  CS100010
# 522970     2013         3        R       전통시장  1001282       약수시장  CS100010
# 522969     2013         3        R       전통시장  1001274      신중부시장  CS100010
# 522968     2013         3        A       골목상권  1000302     종암로21길  CS100010
# 522967     2013         3        A       골목상권  1000715     신길로39길  CS100010
# 522966     2013         3        A       골목상권  1000832        중앙길  CS100010
# 522965     2013         3        A       골목상권  1000799  남부순환로234길  CS100010
# 522964     2013         3        A       골목상권  1000944   백제고분로22길  CS100010
# 522963     2013         3        A       골목상권  1000943   백제고분로21길  CS100010
# ...         ...       ...      ...        ...      ...        ...       ...
# ...
