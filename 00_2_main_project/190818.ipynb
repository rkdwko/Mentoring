# %%
import pandas as pd
import os

# %%
df_population2014 = pd.read_table("C:/Users/709-000/Desktop/새 폴더/연도별 추출(2014~2018)/유동인구2014.csv",sep=',')
df_population2014
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: read_table is deprecated, use read_csv instead.
#   """Entry point for launching an IPython kernel.
#       Unnamed: 0  stdr_yy_cd  stdr_qu_cd trdar_se_cd trdar_se_cd_nm  trdar_cd  \
# 0              0        2014           1           A           골목상권   1000001
# 1              1        2014           1           A           골목상권   1000002
# 2              2        2014           1           A           골목상권   1000003
# 3              3        2014           1           A           골목상권   1000004
# 4              4        2014           1           A           골목상권   1000005
# 5              5        2014           1           A           골목상권   1000006
# 6              6        2014           1           A           골목상권   1000007
# 7              7        2014           1           A           골목상권   1000008
# 8              8        2014           1           A           골목상권   1000009
# ...

# %%
del df_population2014['Unnamed: 0']
df_population2014.head(10)
# Out:
#    stdr_yy_cd  stdr_qu_cd trdar_se_cd trdar_se_cd_nm  trdar_cd trdar_cd_nm  \
# 0        2014           1           A           골목상권   1000001         계동길
# 1        2014           1           A           골목상권   1000002      난계로27길
# 2        2014           1           A           골목상권   1000003    돈화문로11가길
# 3        2014           1           A           골목상권   1000004         명륜길
# 4        2014           1           A           골목상권   1000005        백석동길
# 5        2014           1           A           골목상권   1000006      북촌로11길
# 6        2014           1           A           골목상권   1000007       북촌로5길
# 7        2014           1           A           골목상권   1000008      북촌로5나길
# 8        2014           1           A           골목상권   1000009       삼청로5길
# 9        2014           1           A           골목상권   1000010      성균관로5길
#
#    tot_flpop_co  ml_flpop_co  fml_flpop_co  agrde_10_flpop_co  ...  \
# 0        147154        85726         61430               3250  ...
# ...

# %%
df_population2014.columns
# Out:
# Index(['stdr_yy_cd', 'stdr_qu_cd', 'trdar_se_cd', 'trdar_se_cd_nm', 'trdar_cd',
#        'trdar_cd_nm', 'tot_flpop_co', 'ml_flpop_co', 'fml_flpop_co',
#        'agrde_10_flpop_co',
#        ...
#        'fag_60_above_sattm_3_flpop_co', 'fag_60_above_sattm_4_flpop_co',
#        'fag_60_above_sattm_5_flpop_co', 'fag_60_above_sattm_6_flpop_co',
#        'fag_60_above_suntm_1_flpop_co', 'fag_60_above_suntm_2_flpop_co',
#        'fag_60_above_suntm_3_flpop_co', 'fag_60_above_suntm_4_flpop_co',
#        'fag_60_above_suntm_5_flpop_co', 'fag_60_above_suntm_6_flpop_co'],
#       dtype='object', length=532)

# %%
df_population2014 = df_population_2018[['stdr_yy_cd', 'stdr_qu_cd', 'trdar_se_cd', 'trdar_se_cd_nm', 'trdar_cd', 'trdar_cd_nm', 'tot_flpop_co']]
df_population2014
