# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv('D:/Workspace/Mentoring/00_mini_project/Dataset/2016년+3월+SKT이동통신을+이용한+성별연령별+유동인구(종로구).csv')
df1
# Out:
#       STD_YM SI_DO_NM SGNG_NM ADONG_NM              BLOCK_CD      X_COORD  \
# 0     201603    서울특별시     종로구      평창동  11010560200141000001  952559.0000
# 1     201603    서울특별시     종로구      평창동  11010560200141000001  952608.3750
# 2     201603    서울특별시     종로구      평창동  11010560200141000001  952609.6250
# 3     201603    서울특별시     종로구      평창동  11010560200141000001  952757.5000
# 4     201603    서울특별시     종로구      평창동  11010560200051000001  954573.3750
# 5     201603    서울특별시     종로구      평창동  11010560300051000001  952752.5000
# 6     201603    서울특별시     종로구      평창동  11010560300051000001  953779.8125
# 7     201603    서울특별시     종로구      평창동  11010560300051000001  953925.1875
# 8     201603    서울특별시     종로구      평창동  11010560200141000001  952657.3750
# 9     201603    서울특별시     종로구      평창동  11010560200141000001  952657.6875
# ...      ...      ...     ...      ...                   ...          ...
# 5657  201603    서울특별시     종로구     숭인2동  11010710200021000002  957589.8750
# ...

# %%
df2 = pd.read_csv('D:/Workspace/Mentoring/00_mini_project/Dataset/2016년+3월+SKT이동통신을+이용한+시간대별+유동인구(종로구).csv')
df2
# Out:
#       STD_YM SI_DO_NM SGNG_NM ADONG_NM      BLOCK_CD      X_COORD  Y_COORD  \
# 0     201603    서울특별시     종로구      평창동  1.101060e+19  952559.0000  1956707
# 1     201603    서울특별시     종로구      평창동  1.101060e+19  952608.3750  1956758
# 2     201603    서울특별시     종로구      평창동  1.101060e+19  952609.6250  1956963
# 3     201603    서울특별시     종로구      평창동  1.101060e+19  952657.3750  1956758
# 4     201603    서울특별시     종로구      평창동  1.101060e+19  952657.6875  1956809
# 5     201603    서울특별시     종로구      평창동  1.101060e+19  952657.8750  1956860
# 6     201603    서울특별시     종로구      평창동  1.101060e+19  952658.3125  1956912
# 7     201603    서울특별시     종로구      평창동  1.101060e+19  952658.6250  1956963
# 8     201603    서울특별시     종로구      평창동  1.101060e+19  952707.1250  1956860
# 9     201603    서울특별시     종로구      평창동  1.101060e+19  952707.3125  1956911
# ...      ...      ...     ...      ...           ...          ...      ...
# ...

# %%
df3 = pd.read_csv('D:/Workspace/Mentoring/00_mini_project/Dataset/2016년+3월+SKT이동통신을+이용한+요일별+유동인구(종로구).csv')
df3
# Out:
#       STD_YM SI_DO_NM SGNG_NM ADONG_NM      BLOCK_CD      X_COORD  Y_COORD  \
# 0     201603    서울특별시     종로구      평창동  1.101060e+19  952559.0000  1956707
# 1     201603    서울특별시     종로구      평창동  1.101060e+19  952608.3750  1956758
# 2     201603    서울특별시     종로구      평창동  1.101060e+19  952609.6250  1956963
# 3     201603    서울특별시     종로구      평창동  1.101060e+19  952657.3750  1956758
# 4     201603    서울특별시     종로구      평창동  1.101060e+19  952657.6875  1956809
# 5     201603    서울특별시     종로구      평창동  1.101060e+19  952657.8750  1956860
# 6     201603    서울특별시     종로구      평창동  1.101060e+19  952658.3125  1956912
# 7     201603    서울특별시     종로구      평창동  1.101060e+19  952658.6250  1956963
# 8     201603    서울특별시     종로구      평창동  1.101060e+19  952707.1250  1956860
# 9     201603    서울특별시     종로구      평창동  1.101060e+19  952707.3125  1956911
# ...      ...      ...     ...      ...           ...          ...      ...
# ...
