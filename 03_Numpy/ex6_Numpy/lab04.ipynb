# %%
import os 
print (os.getcwd()) 
 

#1 위의 파일을 읽고, 5행만 출력 
import pandas as pd
pop_Seoul = pd.read_excel("lab04_한국영화박스오피스_2012-2016.xlsx",encording="utf-8")
print(pop_Seoul.head()) #5행만
# Out:
# D:\leeji\PycharmProjects\Python_02_Advanced\01_pandas
# D:\leeji\PycharmProjects\Python_02_Advanced\01_pandas
#           날짜             영화명                  개봉일        매출액     관객수   스크린수   \
# 0 2016-12-31             마스터  2016-12-21 00:00:00  4583498250  537784   1262
# 1 2016-12-31  로그 원: 스타워즈 스토리  2016-12-28 00:00:00  1964415350  213544    828
# 2 2016-12-31               씽  2016-12-21 00:00:00  1062234400  133668    690
# 3 2016-12-31            라라랜드  2016-12-07 00:00:00   932933700  108536    573
# 4 2016-12-31             판도라  2016-12-07 00:00:00   772231000   94765    566
#
#    상영횟수  대표국적                  배급사
# 0   5897    한국            씨제이이앤엠(주)
# 1   3588    미국   월트디즈니컴퍼니코리아 유한책임회사
# 2   1730    미국  유니버설픽쳐스인터내셔널 코리아(유)
# 3   1614    미국              판씨네마(주)
# 4   1505    한국  (주)넥스트엔터테인먼트월드(NEW)

# %%
import matplotlib.pyplot as plt 
# %matplotlib inline
print(pop_Seoul.columns )
print(pop_Seoul.iloc[:,3])
# Out:
# Index(['날짜', '영화명', '개봉일', '매출액 ', '관객수 ', '스크린수 ', '상영횟수 ', '대표국적 ', '배급사 '], dtype='object')
# 0         4583498250
# 1         1964415350
# 2         1062234400
# 3          932933700
# 4          772231000
# 5          293957000
# 6          267632600
# 7          186677200
# 8          196605700
# 9           48123000
# 10          35714100
# 11          23281500
# 12          21891300
# 13          20535200
# 14          19188600
# 15          15248500
# 16          12148100
# 17           6371000
# 18           1590000
# 19           6186100
# 20           4498100
# 21           3931000
# 22           3526000
# 23           2583700
# 24            652000
# 25           5867500
# 26           2606100
# 27           1590500
# 28           1973600
# 29           1645500
#              ...
# 169489        339000
# 169490        963000
# 169491        389000
# 169492        345000
# 169493        313000
# 169494        167000
# 169495        245000
# 169496        182500
# ...

# %%
#2 X축 관객수,  y축 매출액로 그래프를 그리세요. 
plt.figure(figsize=(10,6)) 
plt.plot(pop_Seoul.iloc[:,4], pop_Seoul.iloc[:,3]) 
plt.show()

# %%
#3)	 X축 스크린수,  y축 매출액로 그래프를 그리세요 
plt.figure(figsize=(10,6)) 
plt.plot(pop_Seoul.iloc[:,5], pop_Seoul.iloc[:,3]) 
plt.show()

# %%
#4)	 X축 상영횟수,  y축 매출액로 그래프를 그리세요 
plt.figure(figsize=(10,6)) 
plt.plot(pop_Seoul.iloc[:,6], pop_Seoul.iloc[:,3]) 
plt.show()

# %%
#5)	 스크린수 1000개 이상인 영화 출력 
pop_Seoul[ pop_Seoul["스크린수 "] >=1000 ]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>날짜</th>
#       <th>영화명</th>
#       <th>개봉일</th>
#       <th>매출액</th>
#       <th>관객수</th>
#       <th>스크린수</th>
#       <th>상영횟수</th>
#       <th>대표국적</th>
#       <th>배급사</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2016-12-31</td>
#       <td>마스터</td>
#       <td>2016-12-21 00:00:00</td>
#       <td>4583498250</td>
#       <td>537784</td>
#       <td>1262</td>
#       <td>5897</td>
#       <td>한국</td>
#       <td>씨제이이앤엠(주)</td>
#     </tr>
#     <tr>
#       <th>100</th>
#       <td>2016-12-30</td>
#       <td>마스터</td>
#       <td>2016-12-21 00:00:00</td>
# ...

# %%
#6 대표 국적인 한국인 영화만 출력 
pop_Seoul[ pop_Seoul["대표국적 "] == "한국" ]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>날짜</th>
#       <th>영화명</th>
#       <th>개봉일</th>
#       <th>매출액</th>
#       <th>관객수</th>
#       <th>스크린수</th>
#       <th>상영횟수</th>
#       <th>대표국적</th>
#       <th>배급사</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2016-12-31</td>
#       <td>마스터</td>
#       <td>2016-12-21 00:00:00</td>
#       <td>4583498250</td>
#       <td>537784</td>
#       <td>1262</td>
#       <td>5897</td>
#       <td>한국</td>
#       <td>씨제이이앤엠(주)</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2016-12-31</td>
#       <td>판도라</td>
#       <td>2016-12-07 00:00:00</td>
# ...
