# %%
import os 
print (os.getcwd()) 
  

import pandas as pd 
lab01_data = pd.read_csv("lab01_subway2013.csv",encoding="utf-8")
print(lab01_data.head() )
# Out:
# D:\leeji\PycharmProjects\Python_02_Advanced\01_pandas
# D:\leeji\PycharmProjects\Python_02_Advanced\01_pandas
#    순번         역명      평일     토요일     일요일
# 0   1        신도림  333873  298987  216886
# 1   2  동대문역사문화공원  251049  211456  150589
# 2   3        충무로  229882  194865  142150
# 3   4       종로3가  224539  196606  142525
# 4   5         사당  200985  180230  134354

# %%
lab01_data.index
# Out:
# RangeIndex(start=0, stop=44, step=1)

# %%
lab01_data.columns
# Out:
# Index(['순번', '역명', '평일', '토요일', '일요일'], dtype='object')

# %%
lab01_data.sort_values(by="평일",ascending=True)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>순번</th>
#       <th>역명</th>
#       <th>평일</th>
#       <th>토요일</th>
#       <th>일요일</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>43</th>
#       <td>44</td>
#       <td>이촌</td>
#       <td>12802</td>
#       <td>46939</td>
#       <td>10681</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>43</td>
#       <td>옥수</td>
#       <td>14882</td>
#       <td>12755</td>
#       <td>10099</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>42</td>
#       <td>불광</td>
#       <td>18249</td>
#       <td>15840</td>
#       <td>14222</td>
#     </tr>
#     <tr>
#       <th>40</th>
# ...

# %%
#토요일 환승 인원이 100000명 이상의 역의 역명과 다른 요일 환승인원 출력
print ( lab01_data[ lab01_data["토요일"]>100000])
# Out:
#    순번         역명      평일     토요일     일요일
# 0   1        신도림  333873  298987  216886
# 1   2  동대문역사문화공원  251049  211456  150589
# 2   3        충무로  229882  194865  142150
# 3   4       종로3가  224539  196606  142525
# 4   5         사당  200985  180230  134354
# 5   6      고속터미널  194859  175702  120096
# 6   7         교대  182104  154046   98136
# 7   8         선릉  175262  132869   87621
# 8   9        서울역  141488  138754  108232
# 9  10         시청  120866  104257   78903

# %%
#일요일 환승 인원만 역명과 함께 출력 
lab01_data.loc [  : , ["역명","일요일"]]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>역명</th>
#       <th>일요일</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>신도림</td>
#       <td>216886</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>동대문역사문화공원</td>
#       <td>150589</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>충무로</td>
#       <td>142150</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>종로3가</td>
#       <td>142525</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>사당</td>
#       <td>134354</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>고속터미널</td>
#       <td>120096</td>
#     </tr>
#     <tr>
# ...

# %%
#11~20번째 행의  일요일 환승 인원만 역명과 함께 출력 
lab01_data.loc [ 11:21 , ["역명","일요일"]]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>역명</th>
#       <th>일요일</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>11</th>
#       <td>합정</td>
#       <td>69333</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>대림</td>
#       <td>64075</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>을지3가</td>
#       <td>62281</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>왕십리</td>
#       <td>57027</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>건대입구</td>
#       <td>61085</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>동대문</td>
#       <td>58310</td>
#     </tr>
#     <tr>
#       <th>17</th>
# ...

# %%
lab01_data["역명"].unique()   #역명만 출력.  단 중복해서 출력하지는 말 것.
